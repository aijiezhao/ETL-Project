# %%
pip install psycopg2
# Out:
# Requirement already satisfied: psycopg2 in c:\users\15309\anaconda3\envs\python_data\lib\site-packages (2.8.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Dependencies
import pandas as pd
from sqlalchemy import create_engine

# %%
# Name of the CSV file
file = 'Covid Data.csv'

# %%
# The correct encoding must be used to read the CSV in pandas
df = pd.read_csv(file, header=None)

# %%
# Preview of the DataFrame
# Note that FIELD8 is likely a meaningless column
df.head()
# Out:
#                                                   0                         1  \
# 0  Title: Confirmed COVID-19 Cases and Deaths | KFF                       NaN
# 1              Timeframe: as of 9/14/2020 at 2:26PM                       NaN
# 2                                          Location  Number of COVID-19 Cases
# 3                                     United States                 6,535,105
# 4                                           Alabama                   139,459
#
#                                          2                     3  \
# 0                                      NaN                   NaN
# 1                                      NaN                   NaN
# 2  COVID-19 Cases per 1,000,000 Population  Deaths from COVID-19
# 3                                    19910               194,252
# 4                                    28443                 2,355
#
#                                           4                       5          6
# 0                                       NaN                     NaN        NaN
# 1                                       NaN                     NaN        NaN
# 2  COVID-19 Deaths per 1,000,000 Population  COVID-19 Fatality Rate  Footnotes
# 3                                       592             0.029724389          1
# 4                                       480             0.016886684        NaN

# %%
df = df.drop(index=[0, 1])
df.head()
# Out:
#                0                         1  \
# 2       Location  Number of COVID-19 Cases
# 3  United States                 6,535,105
# 4        Alabama                   139,459
# 5         Alaska                     6,343
# 6        Arizona                   208,512
#
#                                          2                     3  \
# 2  COVID-19 Cases per 1,000,000 Population  Deaths from COVID-19
# 3                                    19910               194,252
# 4                                    28443                 2,355
# 5                                     8671                    44
# 6                                    28647                 5,322
#
#                                           4                       5          6
# 2  COVID-19 Deaths per 1,000,000 Population  COVID-19 Fatality Rate  Footnotes
# 3                                       592             0.029724389          1
# 4                                       480             0.016886684        NaN
# 5                                        60             0.006936781        NaN
# 6                                       731             0.025523711        NaN

# %%
df = df.rename(columns=df.iloc[0]).drop(df.index[0])
df.head()
# Out:
#         Location Number of COVID-19 Cases  \
# 3  United States                6,535,105
# 4        Alabama                  139,459
# 5         Alaska                    6,343
# 6        Arizona                  208,512
# 7       Arkansas                   70,219
#
#   COVID-19 Cases per 1,000,000 Population Deaths from COVID-19  \
# 3                                   19910              194,252
# 4                                   28443                2,355
# 5                                    8671                   44
# 6                                   28647                5,322
# 7                                   23268                  981
#
#   COVID-19 Deaths per 1,000,000 Population COVID-19 Fatality Rate Footnotes
# 3                                      592            0.029724389         1
# 4                                      480            0.016886684       NaN
# 5                                       60            0.006936781       NaN
# 6                                      731            0.025523711       NaN
# 7                                      325            0.013970578       NaN

# %%
df.columns
# Out:
# Index(['Location', 'Number of COVID-19 Cases',
#        'COVID-19 Cases per 1,000,000 Population', 'Deaths from COVID-19',
#        'COVID-19 Deaths per 1,000,000 Population', 'COVID-19 Fatality Rate',
#        'Footnotes'],
#       dtype='object')

# %%
df.columns = ['state', 'number_covid_cases',
       'COVID-19 Cases per 1,000,000 Population', 'number_of_deaths',
       'COVID-19 Deaths per 1,000,000 Population', 'fatality_rate',
       'Footnotes']

# %%
# Delete extraneous column
df = df.drop(columns=['COVID-19 Cases per 1,000,000 Population', 'COVID-19 Deaths per 1,000,000 Population', 'Footnotes'], axis=1)
df.head()
# Out:
#            state number_covid_cases number_of_deaths fatality_rate
# 3  United States          6,535,105          194,252   0.029724389
# 4        Alabama            139,459            2,355   0.016886684
# 5         Alaska              6,343               44   0.006936781
# 6        Arizona            208,512            5,322   0.025523711
# 7       Arkansas             70,219              981   0.013970578

# %%
# Identify incomplete rows
df.count()
# Out:
# state                 65
# number_covid_cases    57
# number_of_deaths      57
# fatality_rate         57
# dtype: int64

# %%
# Drop all rows with missing information
df = df.dropna(how='any')

# %%
# Verify dropped rows
df.count()
# Out:
# state                 57
# number_covid_cases    57
# number_of_deaths      57
# fatality_rate         57
# dtype: int64

# %%
# The Amount column is the wrong data type. It should be numeric.
df.dtypes
# Out:
# state                 object
# number_covid_cases    object
# number_of_deaths      object
# fatality_rate         object
# dtype: object

# %%
# Use pd.to_numeric() method to convert the datatype of the Amount column
df['number_covid_cases'] = df['number_covid_cases'].str.replace(',', '')
df['number_of_deaths'] = df['number_of_deaths'].str.replace(',', '')
df['number_covid_cases'] = pd.to_numeric(df['number_covid_cases'])
#df['COVID-19 Cases per 1,000,000 Population'] = pd.to_numeric(df['COVID-19 Cases per 1,000,000 Population'])
df['number_of_deaths'] = pd.to_numeric(df['number_of_deaths'])
#df['COVID-19 Deaths per 1,000,000 Population'] = pd.to_numeric(df['COVID-19 Deaths per 1,000,000 Population'])
df.dtypes
# Out:
# state                 object
# number_covid_cases     int64
# number_of_deaths       int64
# fatality_rate         object
# dtype: object

# %%
df
# Out:
#                        state  number_covid_cases  number_of_deaths  \
# 3              United States             6535105            194252
# 4                    Alabama              139459              2355
# 5                     Alaska                6343                44
# 6                    Arizona              208512              5322
# 7                   Arkansas               70219               981
# 8                 California              763171             14392
# 9                   Colorado               61293              1988
# 10               Connecticut               54326              4480
# 11                  Delaware               18937               617
# 12      District of Columbia               14622               616
# 13                   Florida              665730             12642
# 14                   Georgia              294314              6333
# 15                    Hawaii               10700                99
# 16                     Idaho               35279               415
# 17                  Illinois              264831              8546
# 18                   Indiana              106540              3439
# 19                      Iowa               74896              1223
# 20                    Kansas               49272               534
# 21                  Kentucky               56945              1060
# 22                 Louisiana              157947              5252
# 23                     Maine                4904               136
# 24                  Maryland              116646              3839
# 25             Massachusetts              124826              9210
# 26                  Michigan              123058              6911
# 27                 Minnesota               84949              1974
# 28               Mississippi               90018              2706
# 29                  Missouri              104080              1731
# 30                   Montana                9107               138
# 31                  Nebraska               38335               434
# 32                    Nevada               73814              1456
# 33             New Hampshire                7696               436
# 34                New Jersey              196968             16034
# 35                New Mexico               26761               823
# 36                  New York              444948             33030
# 37            North Carolina              185780              3060
# 38              North Dakota               15831               170
# 44  0.0232360610.0232360610.0232360610.0232360610....
# 45  0.0109517290.0109517290.0109517290.0109517290....
# 46  0.012093770.012093770.012093770.012093770.0120...
# 47  0.0211146730.0211146730.0211146730.0211146730....
# 48  0.0155610160.0155610160.0155610160.0155610160....
# 49  0.0074816410.0074816410.0074816410.0074816410....
# 50  0.0341981130.0341981130.0341981130.0341981130....
# 51  0.0203951140.0203951140.0203951140.0203951140....
# 52  0.0249417480.0249417480.0249417480.0249417480....
# 53  0.0210153480.0210153480.0210153480.0210153480....
# 54  0.0135673040.0135673040.0135673040.0135673040....
# 55  0.0096640590.0096640590.0096640590.0096640590....
# 56  0000000000000000000000000000000000000000000000...
# 57  0.0134924750.0134924750.0134924750.0134924750....
# 58  0.0327868850.0327868850.0327868850.0327868850....
# 59  0.0143576160.0143576160.0143576160.0143576160....

# %%
df.to_csv('Covid_clean.csv', index = False)

# %%
rds_connection_string = "postgres:postgres@localhost:5432/ETL_Project"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['covid_19', 'population', 'obesity']

# %%
df.to_sql(name='covid_19', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# ~\anaconda3\envs\Python_Data\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1256                     self.dialect.do_executemany(
# -> 1257                         cursor, statement, parameters, context
#    1258                     )
#
# ~\anaconda3\envs\Python_Data\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     872         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 873             cursor.executemany(statement, parameters)
#     874             return
#
# UniqueViolation: duplicate key value violates unique constraint "covid_19_pkey"
# DETAIL:  Key (state)=(United States) already exists.
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-19-a901919a1feb> in <module>
# ----> 1 df.to_sql(name='covid_19', con=engine, if_exists='append', index=False)
#
# ~\anaconda3\envs\Python_Data\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2661             chunksize=chunksize,
#    2662             dtype=dtype,
# -> 2663             method=method,
#    2664         )
#    2665
#
# ~\anaconda3\envs\Python_Data\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     519         chunksize=chunksize,
#     520         dtype=dtype,
# --> 521         method=method,
#     522     )
#     523
#
# ~\anaconda3\envs\Python_Data\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1315         )
#    1316         table.create()
# -> 1317         table.insert(chunksize, method=method)
#    1318         if not name.isdigit() and not name.islower():
#    1319             # check for potentially case sensitivity issues (GH7815)
#
# ~\anaconda3\envs\Python_Data\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     753
#     754                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 755                 exec_insert(conn, keys, chunk_iter)
#     756
#     757     def _query_iterator(
#
# ~\anaconda3\envs\Python_Data\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     667         """
#     668         data = [dict(zip(keys, row)) for row in data_iter]
# --> 669         conn.execute(self.table.insert(), data)
#     670
#     671     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~\anaconda3\envs\Python_Data\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#    1009             )
#    1010         else:
# -> 1011             return meth(self, multiparams, params)
#    1012
#    1013     def _execute_function(self, func, multiparams, params):
#
# ~\anaconda3\envs\Python_Data\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     296     def _execute_on_connection(self, connection, multiparams, params):
#     297         if self.supports_execution:
# --> 298             return connection._execute_clauseelement(self, multiparams, params)
#     299         else:
#     300             raise exc.ObjectNotExecutableError(self)
#
# ~\anaconda3\envs\Python_Data\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1128             distilled_params,
#    1129             compiled_sql,
# -> 1130             distilled_params,
#    1131         )
#    1132         if self._has_events or self.engine._has_events:
#
# ~\anaconda3\envs\Python_Data\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1315         except BaseException as e:
#    1316             self._handle_dbapi_exception(
# -> 1317                 e, statement, parameters, cursor, context
#    1318             )
#    1319
#
# ~\anaconda3\envs\Python_Data\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1509             elif should_wrap:
#    1510                 util.raise_(
# -> 1511                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1512                 )
#    1513             else:
#
# ~\anaconda3\envs\Python_Data\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~\anaconda3\envs\Python_Data\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1255                 if not evt_handled:
#    1256                     self.dialect.do_executemany(
# -> 1257                         cursor, statement, parameters, context
#    1258                     )
#    1259             elif not parameters and context.no_parameters:
#
# ~\anaconda3\envs\Python_Data\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     871     def do_executemany(self, cursor, statement, parameters, context=None):
#     872         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 873             cursor.executemany(statement, parameters)
#     874             return
#     875
#
# IntegrityError: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "covid_19_pkey"
# DETAIL:  Key (state)=(United States) already exists.
#
# [SQL: INSERT INTO covid_19 (state, number_covid_cases, number_of_deaths, fatality_rate) VALUES (%(state)s, %(number_covid_cases)s, %(number_of_deaths)s, %(fatality_rate)s)]
# [parameters: ({'state': 'United States', 'number_covid_cases': 6535105, 'number_of_deaths': 194252, 'fatality_rate': '0.029724389'}, {'state': 'Alabama', 'number_covid_cases': 139459, 'number_of_deaths': 2355, 'fatality_rate': '0.016886684'}, {'state': 'Alaska', 'number_covid_cases': 6343, 'number_of_deaths': 44, 'fatality_rate': '0.006936781'}, {'state': 'Arizona', 'number_covid_cases': 208512, 'number_of_deaths': 5322, 'fatality_rate': '0.025523711'}, {'state': 'Arkansas', 'number_covid_cases': 70219, 'number_of_deaths': 981, 'fatality_rate': '0.013970578'}, {'state': 'California', 'number_covid_cases': 763171, 'number_of_deaths': 14392, 'fatality_rate': '0.018858159'}, {'state': 'Colorado', 'number_covid_cases': 61293, 'number_of_deaths': 1988, 'fatality_rate': '0.032434373'}, {'state': 'Connecticut', 'number_covid_cases': 54326, 'number_of_deaths': 4480, 'fatality_rate': '0.082465118'}  ... displaying 10 of 57 total bound parameter sets ...  {'state': 'Northern Mariana Islands', 'number_covid_cases': 61, 'number_of_deaths': 2, 'fatality_rate': '0.032786885'}, {'state': 'Puerto Rico', 'number_covid_cases': 37750, 'number_of_deaths': 542, 'fatality_rate': '0.014357616'})]
# (Background on this error at: http://sqlalche.me/e/13/gkpj)
