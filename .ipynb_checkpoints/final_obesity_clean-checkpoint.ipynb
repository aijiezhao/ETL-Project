# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sqlalchemy import create_engine

# %%
obese_data = "Obesity.csv"

# %%
obese_df = pd.read_csv(obese_data)

# %%
new_df = obese_df.loc[(obese_df['Class'] == 'Obesity / Weight Status')]

# %%
second_df = new_df.drop_duplicates()
second_df
# Out:
#        YearStart  YearEnd LocationAbbr          LocationDesc  \
# 0           2012     2012           WY               Wyoming
# 1           2012     2012           DC  District of Columbia
# 2           2011     2011           AL               Alabama
# 7           2015     2015           RI          Rhode Island
# 10          2011     2011           WA            Washington
# ...          ...      ...          ...                   ...
# 63017       2014     2014           OK              Oklahoma
# 63019       2013     2013           MS           Mississippi
# 63024       2014     2014           SC        South Carolina
# 63025       2011     2011           MS           Mississippi
# 63026       2012     2012           MS           Mississippi
#
#                                        Datasource                    Class  \
# 0      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 1      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 7      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 10     Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# ...                                           ...                      ...
# 63017  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 63019  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 63024  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 63025  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 63026  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
#
#                          Topic  \
# 0      Obesity / Weight Status
# 1      Obesity / Weight Status
# 2      Obesity / Weight Status
# 7      Obesity / Weight Status
# 10     Obesity / Weight Status
# ...                        ...
# 63017  Obesity / Weight Status
# 63019  Obesity / Weight Status
# 63024  Obesity / Weight Status
# 63025  Obesity / Weight Status
# 63026  Obesity / Weight Status
#
#                                                 Question  Data_Value_Unit  \
# 0      Percent of adults aged 18 years and older who ...              NaN
# 1      Percent of adults aged 18 years and older who ...              NaN
# 2      Percent of adults aged 18 years and older who ...              NaN
# 7      Percent of adults aged 18 years and older who ...              NaN
# 10     Percent of adults aged 18 years and older who ...              NaN
# ...                                                  ...              ...
# 63017  Percent of adults aged 18 years and older who ...              NaN
# 63019  Percent of adults aged 18 years and older who ...              NaN
# 63024  Percent of adults aged 18 years and older who ...              NaN
# 63025  Percent of adults aged 18 years and older who ...              NaN
# 63026  Percent of adults aged 18 years and older who ...              NaN
#
#       Data_Value_Type  ...                     GeoLocation  ClassID TopicID  \
# 0               Value  ...  (43.235541343, -108.109830353)      OWS    OWS1
# 1               Value  ...   (38.890371385, -77.031961127)      OWS    OWS1
# 2               Value  ...   (32.840571122, -86.631860762)      OWS    OWS1
# 7               Value  ...   (41.708280193, -71.522470314)      OWS    OWS1
# 10              Value  ...   (47.522278629, -120.47001079)      OWS    OWS1
# ...               ...  ...                             ...      ...     ...
# 63017           Value  ...   (35.472031356, -97.521070214)      OWS    OWS1
# 63019           Value  ...   (32.745510099, -89.538030825)      OWS    OWS1
# 63024           Value  ...   (33.998821303, -81.045371207)      OWS    OWS1
# 63025           Value  ...   (32.745510099, -89.538030825)      OWS    OWS1
# 63026           Value  ...   (32.745510099, -89.538030825)      OWS    OWS1
#
#       QuestionID  DataValueTypeID  LocationID  StratificationCategory1  \
# 0           Q037            VALUE          56           Race/Ethnicity
# 1           Q036            VALUE          11                Education
# 2           Q036            VALUE           1              Age (years)
# 7           Q037            VALUE          44           Race/Ethnicity
# 10          Q037            VALUE          53                   Gender
# ...          ...              ...         ...                      ...
# 63017       Q036            VALUE          40                   Income
# 63019       Q036            VALUE          28                   Income
# 63024       Q037            VALUE          45           Race/Ethnicity
# 63025       Q036            VALUE          28           Race/Ethnicity
# 63026       Q036            VALUE          28                Education
#
#                         Stratification1 StratificationCategoryId1  \
# 0         American Indian/Alaska Native                      RACE
# 1                 Less than high school                       EDU
# 2                               25 - 34                     AGEYR
# 7                              Hispanic                      RACE
# 10                                 Male                       GEN
# ...                                 ...                       ...
# 63017                 $25,000 - $34,999                       INC
# 63019                 $50,000 - $74,999                       INC
# 63024                   2 or more races                      RACE
# 63025                             Asian                      RACE
# 63026  Some college or technical school                       EDU
#
#       StratificationID1
# 0               RACENAA
# 1                 EDUHS
# 2             AGEYR2534
# 7               RACEHIS
# 10                 MALE
# ...                 ...
# 63017           INC2535
# 63019           INC5075
# 63024         RACE2PLUS
# 63025           RACEASN
# 63026          EDUCOTEC
#
# [24080 rows x 33 columns]

# %%
third_df = second_df.loc[(second_df['YearStart'] == 2018)]

# %%
df = third_df.drop(columns=['YearEnd', 'LocationAbbr', 'Datasource', 'Class', 'Topic', 'Data_Value_Unit', 'Data_Value_Type', 'Data_Value_Alt', 'Data_Value_Footnote_Symbol', 'Data_Value_Footnote', 'Low_Confidence_Limit', 'Total', 'Age(years)', 'Education', 'Gender', 'Income', 'Race/Ethnicity', 'GeoLocation', 'ClassID', 'TopicID', 'QuestionID', 'DataValueTypeID', 'LocationID', 'StratificationCategory1', 'Stratification1', 'StratificationCategoryId1', 'StratificationID1'])

# %%
#df
new_sorted_df = df.drop(columns=['Sample_Size'])
sorted_df = new_sorted_df.loc[new_sorted_df['Question'] == 'Percent of adults aged 18 years and older who have obesity']
sorted_df
# Out:
#        YearStart    LocationDesc  \
# 7809        2018        National
# 7968        2018           Idaho
# 7985        2018         Indiana
# 8253        2018    South Dakota
# 8400        2018          Nevada
# ...          ...             ...
# 14843       2018        Kentucky
# 14845       2018  Virgin Islands
# 14848       2018            Utah
# 14850       2018  North Carolina
# 14855       2018        Maryland
#
#                                                 Question  Data_Value  \
# 7809   Percent of adults aged 18 years and older who ...        31.3
# 7968   Percent of adults aged 18 years and older who ...        32.9
# 7985   Percent of adults aged 18 years and older who ...        34.2
# 8253   Percent of adults aged 18 years and older who ...        32.0
# 8400   Percent of adults aged 18 years and older who ...        41.3
# ...                                                  ...         ...
# 14843  Percent of adults aged 18 years and older who ...        30.8
# 14845  Percent of adults aged 18 years and older who ...         NaN
# 14848  Percent of adults aged 18 years and older who ...        24.5
# 14850  Percent of adults aged 18 years and older who ...        16.7
# 14855  Percent of adults aged 18 years and older who ...        41.8
#
#        High_Confidence_Limit
# 7809                     31.7
# 7968                     39.0
# 7985                     36.2
# 8253                     39.5
# 8400                     51.1
# ...                       ...
# 14843                    33.7
# 14845                     NaN
# 14848                    26.1
# 14850                    21.6
# 14855                    55.2
#
# [1540 rows x 5 columns]

# %%
final_df = sorted_df.drop(columns=['High_Confidence_Limit '])

# %%
final_df
# Out:
#        YearStart    LocationDesc  \
# 7809        2018        National
# 7968        2018           Idaho
# 7985        2018         Indiana
# 8253        2018    South Dakota
# 8400        2018          Nevada
# ...          ...             ...
# 14843       2018        Kentucky
# 14845       2018  Virgin Islands
# 14848       2018            Utah
# 14850       2018  North Carolina
# 14855       2018        Maryland
#
#                                                 Question  Data_Value
# 7809   Percent of adults aged 18 years and older who ...        31.3
# 7968   Percent of adults aged 18 years and older who ...        32.9
# 7985   Percent of adults aged 18 years and older who ...        34.2
# 8253   Percent of adults aged 18 years and older who ...        32.0
# 8400   Percent of adults aged 18 years and older who ...        41.3
# ...                                                  ...         ...
# 14843  Percent of adults aged 18 years and older who ...        30.8
# 14845  Percent of adults aged 18 years and older who ...         NaN
# 14848  Percent of adults aged 18 years and older who ...        24.5
# 14850  Percent of adults aged 18 years and older who ...        16.7
# 14855  Percent of adults aged 18 years and older who ...        41.8
#
# [1540 rows x 4 columns]

# %%
etl_df = final_df.rename(columns={'YearStart': 'Year', 'LocationDesc': 'state', 'Question': 'question', 'Data_Value': 'data_value'})

# %%
final_df = etl_df.drop(index=7809, columns=['Year'])

# %%
final_df
# Out:
#                 state                                           question  \
# 7968            Idaho  Percent of adults aged 18 years and older who ...
# 7985          Indiana  Percent of adults aged 18 years and older who ...
# 8253     South Dakota  Percent of adults aged 18 years and older who ...
# 8400           Nevada  Percent of adults aged 18 years and older who ...
# 8401   South Carolina  Percent of adults aged 18 years and older who ...
# ...               ...                                                ...
# 14843        Kentucky  Percent of adults aged 18 years and older who ...
# 14845  Virgin Islands  Percent of adults aged 18 years and older who ...
# 14848            Utah  Percent of adults aged 18 years and older who ...
# 14850  North Carolina  Percent of adults aged 18 years and older who ...
# 14855        Maryland  Percent of adults aged 18 years and older who ...
#
#        data_value
# 7968         32.9
# 7985         34.2
# 8253         32.0
# 8400         41.3
# 8401         36.8
# ...           ...
# 14843        30.8
# 14845         NaN
# 14848        24.5
# 14850        16.7
# 14855        41.8
#
# [1539 rows x 3 columns]

# %%
final_df = final_df.drop_duplicates(subset = 'state')

# %%
df = final_df.dropna()

# %%
df['data_value'] = pd.to_numeric(df['data_value'])
# Out:
# /Users/zhaoaijie/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df.to_csv('obesity_clean.csv', index=False)

# %%
rds_connection_string = "postgres:postgres@localhost:5432/ETL_Project"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2275         try:
# -> 2276             return fn()
#    2277         except dialect.dbapi.Error as e:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in connect(self)
#     362         if not self._use_threadlocal:
# --> 363             return _ConnectionFairy._checkout(self)
#     364
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     772         if not fairy:
# --> 773             fairy = _ConnectionRecord.checkout(pool)
#     774
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     138                 with util.safe_reraise():
# --> 139                     self._dec_overflow()
#     140         else:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.reraise(exc_type, exc_value, exc_tb)
#      69         else:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     152             raise value.with_traceback(tb)
# --> 153         raise value
#     154
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     135             try:
# --> 136                 return self._create_connection()
#     137             except:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     307
# --> 308         return _ConnectionRecord(self)
#     309
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     436         if connect:
# --> 437             self.__connect(first_connect_check=True)
#     438         self.finalize_callback = deque()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     651             self.starttime = time.time()
# --> 652             connection = pool._invoke_creator(self)
#     653             pool.logger.debug("Created new connection %r", connection)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     488     def connect(self, *cargs, **cparams):
# --> 489         return self.dbapi.connect(*cargs, **cparams)
#     490
#
# ~/opt/anaconda3/lib/python3.7/site-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#
# OperationalError: FATAL:  role "postgres" does not exist
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-19-d72bc75a6b62> in <module>
# ----> 1 engine.table_names()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in table_names(self, schema, connection)
#    2254         """
#    2255
# -> 2256         with self._optional_conn_ctx_manager(connection) as conn:
#    2257             return self.dialect.get_table_names(conn, schema)
#    2258
#
# ~/opt/anaconda3/lib/python3.7/contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _optional_conn_ctx_manager(self, connection)
#    2038     def _optional_conn_ctx_manager(self, connection=None):
#    2039         if connection is None:
# -> 2040             with self._contextual_connect() as conn:
#    2041                 yield conn
#    2042         else:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _contextual_connect(self, close_with_result, **kwargs)
#    2240         return self._connection_cls(
#    2241             self,
# -> 2242             self._wrap_pool_connect(self.pool.connect, None),
#    2243             close_with_result=close_with_result,
#    2244             **kwargs
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2278             if connection is None:
#    2279                 Connection._handle_dbapi_exception_noconnection(
# -> 2280                     e, dialect, self
#    2281                 )
#    2282             else:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1545             util.raise_from_cause(newraise, exc_info)
#    1546         elif should_wrap:
# -> 1547             util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1548         else:
#    1549             util.reraise(*exc_info)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     396     exc_type, exc_value, exc_tb = exc_info
#     397     cause = exc_value if exc_value is not exception else None
# --> 398     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     399
#     400
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     150             value.__cause__ = cause
#     151         if value.__traceback__ is not tb:
# --> 152             raise value.with_traceback(tb)
#     153         raise value
#     154
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2274         dialect = self.dialect
#    2275         try:
# -> 2276             return fn()
#    2277         except dialect.dbapi.Error as e:
#    2278             if connection is None:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in connect(self)
#     361         """
#     362         if not self._use_threadlocal:
# --> 363             return _ConnectionFairy._checkout(self)
#     364
#     365         try:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     771     def _checkout(cls, pool, threadconns=None, fairy=None):
#     772         if not fairy:
# --> 773             fairy = _ConnectionRecord.checkout(pool)
#     774
#     775             fairy._pool = pool
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     490     @classmethod
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#     494             dbapi_connection = rec.get_connection()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     137             except:
#     138                 with util.safe_reraise():
# --> 139                     self._dec_overflow()
#     140         else:
#     141             return self._do_get()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.reraise(exc_type, exc_value, exc_tb)
#      69         else:
#      70             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     151         if value.__traceback__ is not tb:
#     152             raise value.with_traceback(tb)
# --> 153         raise value
#     154
#     155     def u(s):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     134         if self._inc_overflow():
#     135             try:
# --> 136                 return self._create_connection()
#     137             except:
#     138                 with util.safe_reraise():
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     306         """Called by subclasses to create a new ConnectionRecord."""
#     307
# --> 308         return _ConnectionRecord(self)
#     309
#     310     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     435         self.__pool = pool
#     436         if connect:
# --> 437             self.__connect(first_connect_check=True)
#     438         self.finalize_callback = deque()
#     439
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     650         try:
#     651             self.starttime = time.time()
# --> 652             connection = pool._invoke_creator(self)
#     653             pool.logger.debug("Created new connection %r", connection)
#     654             self.connection = connection
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     487
#     488     def connect(self, *cargs, **cparams):
# --> 489         return self.dbapi.connect(*cargs, **cparams)
#     490
#     491     def create_connect_args(self, url):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#     129         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) FATAL:  role "postgres" does not exist
#
# (Background on this error at: http://sqlalche.me/e/e3q8)

# %%
df.to_sql(name='obesity', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# ~\anaconda3\envs\Python_Data\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1256                     self.dialect.do_executemany(
# -> 1257                         cursor, statement, parameters, context
#    1258                     )
#
# ~\anaconda3\envs\Python_Data\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     872         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 873             cursor.executemany(statement, parameters)
#     874             return
#
# UniqueViolation: duplicate key value violates unique constraint "obesity_pkey"
# DETAIL:  Key (state)=(Idaho) already exists.
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-22-249ed8657631> in <module>
# ----> 1 df.to_sql(name='obesity', con=engine, if_exists='append', index=False)
#
# ~\anaconda3\envs\Python_Data\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2661             chunksize=chunksize,
#    2662             dtype=dtype,
# -> 2663             method=method,
#    2664         )
#    2665
#
# ~\anaconda3\envs\Python_Data\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     519         chunksize=chunksize,
#     520         dtype=dtype,
# --> 521         method=method,
#     522     )
#     523
#
# ~\anaconda3\envs\Python_Data\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1315         )
#    1316         table.create()
# -> 1317         table.insert(chunksize, method=method)
#    1318         if not name.isdigit() and not name.islower():
#    1319             # check for potentially case sensitivity issues (GH7815)
#
# ~\anaconda3\envs\Python_Data\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     753
#     754                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 755                 exec_insert(conn, keys, chunk_iter)
#     756
#     757     def _query_iterator(
#
# ~\anaconda3\envs\Python_Data\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     667         """
#     668         data = [dict(zip(keys, row)) for row in data_iter]
# --> 669         conn.execute(self.table.insert(), data)
#     670
#     671     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~\anaconda3\envs\Python_Data\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#    1009             )
#    1010         else:
# -> 1011             return meth(self, multiparams, params)
#    1012
#    1013     def _execute_function(self, func, multiparams, params):
#
# ~\anaconda3\envs\Python_Data\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     296     def _execute_on_connection(self, connection, multiparams, params):
#     297         if self.supports_execution:
# --> 298             return connection._execute_clauseelement(self, multiparams, params)
#     299         else:
#     300             raise exc.ObjectNotExecutableError(self)
#
# ~\anaconda3\envs\Python_Data\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1128             distilled_params,
#    1129             compiled_sql,
# -> 1130             distilled_params,
#    1131         )
#    1132         if self._has_events or self.engine._has_events:
#
# ~\anaconda3\envs\Python_Data\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1315         except BaseException as e:
#    1316             self._handle_dbapi_exception(
# -> 1317                 e, statement, parameters, cursor, context
#    1318             )
#    1319
#
# ~\anaconda3\envs\Python_Data\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1509             elif should_wrap:
#    1510                 util.raise_(
# -> 1511                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1512                 )
#    1513             else:
#
# ~\anaconda3\envs\Python_Data\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~\anaconda3\envs\Python_Data\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1255                 if not evt_handled:
#    1256                     self.dialect.do_executemany(
# -> 1257                         cursor, statement, parameters, context
#    1258                     )
#    1259             elif not parameters and context.no_parameters:
#
# ~\anaconda3\envs\Python_Data\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     871     def do_executemany(self, cursor, statement, parameters, context=None):
#     872         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 873             cursor.executemany(statement, parameters)
#     874             return
#     875
#
# IntegrityError: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "obesity_pkey"
# DETAIL:  Key (state)=(Idaho) already exists.
#
# [SQL: INSERT INTO obesity (state, question, data_value) VALUES (%(state)s, %(question)s, %(data_value)s)]
# [parameters: ({'state': 'Idaho', 'question': 'Percent of adults aged 18 years and older who have obesity', 'data_value': 32.9}, {'state': 'Indiana', 'question': 'Percent of adults aged 18 years and older who have obesity', 'data_value': 34.2}, {'state': 'South Dakota', 'question': 'Percent of adults aged 18 years and older who have obesity', 'data_value': 32.0}, {'state': 'Nevada', 'question': 'Percent of adults aged 18 years and older who have obesity', 'data_value': 41.3}, {'state': 'South Carolina', 'question': 'Percent of adults aged 18 years and older who have obesity', 'data_value': 36.8}, {'state': 'Wisconsin', 'question': 'Percent of adults aged 18 years and older who have obesity', 'data_value': 31.4}, {'state': 'New Mexico', 'question': 'Percent of adults aged 18 years and older who have obesity', 'data_value': 30.8}, {'state': 'Oklahoma', 'question': 'Percent of adults aged 18 years and older who have obesity', 'data_value': 34.0}  ... displaying 10 of 49 total bound parameter sets ...  {'state': 'Pennsylvania', 'question': 'Percent of adults aged 18 years and older who have obesity', 'data_value': 28.3}, {'state': 'Arkansas', 'question': 'Percent of adults aged 18 years and older who have obesity', 'data_value': 30.6})]
# (Background on this error at: http://sqlalche.me/e/13/gkpj)
